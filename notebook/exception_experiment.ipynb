# %%
print("all ok")
# Out:
# all ok

# %%
import sys, os

sys.path.append(os.path.abspath(".."))

# %%
from logger.custom_logger import CustomLogger

# %%
logger = CustomLogger().get_logger("exception_experiment")

# %%
import sys
import traceback

# %%
class DocumentPortalException (Exception):
    """Custom Exception for Document Portal Application"""
    def __init__(self, error_message:str, error_details:sys):
        _, _, exec_tb = error_details.exc_info()
        self.file_name = exec_tb.tb_frame.f_code.co_filename
        self.line_number = exec_tb.tb_lineno
        self.error_message = str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info()))

        
    def __str__(self):
        return f"""Error in [{self.file_name}] at line [{self.lineno}] 
        Message: {self.error_message} 
        Traceback:
        {self.traceback_str}
        """

            
if __name__ == "__main__":
    try:
        # Simulate an error
        a= 1 / 0
        print(a)
    except Exception as e:
        app_exec = DocumentPortalException(e, sys)
        logger.error(app_exec)
        raise app_exec
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\sahat\AppData\Local\Temp\ipykernel_1236\1778822599.py", line 22, in <module>
#     a= 1 / 0
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\logging\__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\logging\__init__.py", line 366, in getMessage
#     msg = str(self.msg)
#   File "C:\Users\sahat\AppData\Local\Temp\ipykernel_1236\1778822599.py", line 12, in __str__
#     return f"""Error in [{self.file_name}] at line [{self.lineno}]
# AttributeError: 'DocumentPortalException' object has no attribute 'lineno'
# Call stack:
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\sahat\AppData\Local\Temp\ipykernel_1236\1778822599.py", line 26, in <module>
#     logger.error(app_exec)
# Message: DocumentPortalException(ZeroDivisionError('division by zero'), <module 'sys' (built-in)>)
# Arguments: ()
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 22
#      20 try:
#      21     # Simulate an error
# ---> 22     a= 1 / 0
#      23     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[11], line 27
#      26 logger.error(app_exec)
# ---> 27 raise app_exec
#
# <class 'str'>: (<class 'AttributeError'>, AttributeError("'DocumentPortalException' object has no attribute 'lineno'"))
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\IPython\core\interactiveshell.py:2181, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2178         traceback.print_exc()
#    2179         return None
# -> 2181     self._showtraceback(etype, value, stb)
#    2182 if self.call_pdb:
#    2183     # drop into debugger
#    2184     self.debugger(force=True)
#
# File e:\Tanmoy Saha\Upskill\Tech Stack\Projects\Document Portal\env\lib\site-packages\ipykernel\zmqshell.py:673, in ZMQInteractiveShell._showtraceback(self, etype, evalue, stb)
#     667 sys.stdout.flush()
#     668 sys.stderr.flush()
#     670 exc_content = {
#     671     "traceback": stb,
#     672     "ename": str(etype.__name__),
# --> 673     "evalue": str(evalue),
#     674 }
#     676 dh = self.displayhook
#     677 # Send exception info over pub socket for other clients than the caller
#     678 # to pick up
#
# Cell In[11], line 12, in DocumentPortalException.__str__(self)
#      11 def __str__(self):
# ---> 12     return f"""Error in [{self.file_name}] at line [{self.lineno}]
#      13     Message: {self.error_message}
#      14     Traceback:
#      15     {self.traceback_str}
#      16     """
#
# AttributeError: 'DocumentPortalException' object has no attribute 'lineno'
