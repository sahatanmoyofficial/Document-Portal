# %%
print("All ok")
# Out:
# All ok

# %%
import logging
import os
from datetime import datetime

# %%
logs_dir = os.path.join(os.getcwd(), "logs")

# %%
os.makedirs(logs_dir, exist_ok=True)

# %%
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"

# %%
LOG_FILE
# Out:
# '11_25_2025_13_47_51.log'

# %%
LOG_FILE_PATH = os.path.join(logs_dir, LOG_FILE)

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
    level=logging.INFO,
)

# %%
logger = logging.getLogger("DocumentPortal")

# %%
logger.info("Logging is set up.")

# %%
import structlog

# %%
log = structlog.get_logger()
log.info("Structlog is set up.", user_id = 123, action="login", filename = "sample.pdf")
# Out:
# 2025-11-25 13:47:51 [info     ] Structlog is set up.           action=login filename=sample.pdf user_id=123

# %%
log.error("Failed to process PDF", user_id = 123, error = "File not found")
# Out:
# 2025-11-25 13:49:03 [error    ] Failed to process PDF          error='File not found' user_id=123
